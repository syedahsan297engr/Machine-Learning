# %%
#importing the library here
import pandas as pd

# %%
#initializing the series as
s = pd.Series([3,5,5,9,6])
s
# Out:
# 0    3
# 1    5
# 2    5
# 3    9
# 4    6
# dtype: int64

# %%
#will show the series
s.head()
# Out:
# 0    3
# 1    5
# 2    5
# 3    9
# 4    6
# dtype: int64

# %%
#reading data through panda
#importing data from url
ufo = pd.read_table("http://bit.ly/uforeports", sep = ",") #ufo is just as a variable, u have to use this now let's see

# %%
#will show 1st 5 rows
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo["State"] #see the state in above table u read that
# Out:
# 0        NY
# 1        NJ
# 2        CO
# 3        KS
# 4        NY
#          ..
# 18236    IL
# 18237    IA
# 18238    WI
# 18239    WI
# 18240    FL
# Name: State, Length: 18241, dtype: object

# %%
#a new column of location and in which there is City and State combined sep by comma which are already present in our data set
ufo["Location"] = ufo.City + " , " + ufo.State #concatenation here introduce the new column
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                     Location
# 0                Ithaca , NY
# 1           Willingboro , NJ
# 2               Holyoke , CO
# 3               Abilene , KS
# 4  New York Worlds Fair , NY

# %%
#it will give us u say how many rows an addition of rows , column
ufo.shape
# Out:
# (18241, 6)

# %%
#just rows*column
ufo.size
# Out:
# 109446

# %%
#print the column of location
ufo["Location"]
# Out:
# 0                      Ithaca , NY
# 1                 Willingboro , NJ
# 2                     Holyoke , CO
# 3                     Abilene , KS
# 4        New York Worlds Fair , NY
#                    ...
# 18236              Grant Park , IL
# 18237             Spirit Lake , IA
# 18238             Eagle River , WI
# 18239             Eagle River , WI
# 18240                    Ybor , FL
# Name: Location, Length: 18241, dtype: object

# %%
#data type which may be an object
ufo.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# Location           object
# dtype: object

# %%
#headings of column and also data type
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time',
#        'Location'],
#       dtype='object')

# %%
#lets start removing and sorting in pandas
ufo = pd.read_table("http://bit.ly/uforeports", sep = ",")
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
#deleting the column
ufo.drop("Colors Reported", axis = 1, inplace = True)
ufo.head()
# Out:
#                    City Shape Reported State             Time
# 0                Ithaca       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00

# %%
#deleting 2 columns at a time
ufo.drop(["State", "Time"], axis = 1, inplace = True) #multiple columns removal
ufo.head()
# Out:
#                    City Shape Reported
# 0                Ithaca       TRIANGLE
# 1           Willingboro          OTHER
# 2               Holyoke           OVAL
# 3               Abilene           DISK
# 4  New York Worlds Fair          LIGHT

# %%
ufo = pd.read_table("http://bit.ly/uforeports", sep = ",")
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
#getting first 25 values acc. to desc order for State
ufo.State.sort_values(ascending = False).head(25) #head() by default 5 if just write head all accessed if wanna access 25 write as written
# Out:
# 1461     WY
# 1442     WY
# 2437     WY
# 5065     WY
# 1985     WY
# 14586    WY
# 12063    WY
# 12072    WY
# 12079    WY
# 2267     WY
# 13839    WY
# 13825    WY
# 3982     WY
# 13823    WY
# 14618    WY
# 15359    WY
# 13756    WY
# 7684     WY
# 13716    WY
# 5232     WY
# 12215    WY
# 3328     WY
# 2109     WY
# 13666    WY
# 3326     WY
# Name: State, dtype: object

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.sort_values("State")
# Out:
#                             City Colors Reported Shape Reported State  \
# 10454                  Anchorage             NaN       CYLINDER    AK
# 14421                     Seward             NaN          LIGHT    AK
# 3511               Kodiak Island             NaN         CIRCLE    AK
# 103                    Anchorage             NaN           DISK    AK
# 2929                      Nulato             NaN          LIGHT    AK
# ...                          ...             ...            ...   ...
# 3326                      Casper             NaN         CIRCLE    WY
# 4866                     Wyoming             NaN          OTHER    WY
# 11333                  Ten Sleep             NaN           DISK    WY
# 11490                   Cheyenne             NaN            NaN    WY
# 12079  Medicine Bow Natl. Forest             NaN       TRIANGLE    WY
#
#                   Time
# 10454  6/30/1997 12:00
# 14421   9/2/1999 21:00
# 3511    6/15/1977 2:00
# 103    6/10/1949 21:00
# ...

# %%
ufo.sort_values("City")
# Out:
#             City Colors Reported Shape Reported State              Time
# 1761   Abbeville             NaN           DISK    SC   12/10/1968 0:30
# 4553    Aberdeen             NaN       CYLINDER    WA   6/15/1981 22:00
# 16167   Aberdeen             NaN        VARIOUS    OH    3/29/2000 3:00
# 14703   Aberdeen             NaN       TRIANGLE    WA   9/30/1999 21:00
# 389     Aberdeen          ORANGE         CIRCLE    SD  11/15/1956 18:30
# ...          ...             ...            ...   ...               ...
# 12441        NaN             RED       FIREBALL    WA  10/26/1998 17:58
# 15767        NaN             NaN      RECTANGLE    NV   1/21/2000 11:30
# 15812        NaN             NaN          LIGHT    NV     2/2/2000 3:00
# 16054        NaN           GREEN            NaN    FL    3/11/2000 3:30
# 16608        NaN             NaN         SPHERE    NY   6/15/2000 15:00
#
# [18241 rows x 5 columns]

# %%
#state and city both sorted at a time State sorted acc. to City
ufo.sort_values(["City", "State"]).head()
# Out:
#             City Colors Reported Shape Reported State              Time
# 1761   Abbeville             NaN           DISK    SC   12/10/1968 0:30
# 2297    Aberdeen             NaN       TRIANGLE    MD    8/18/1972 1:30
# 9404    Aberdeen             NaN           DISK    MD   6/15/1996 13:30
# 16167   Aberdeen             NaN        VARIOUS    OH    3/29/2000 3:00
# 389     Aberdeen          ORANGE         CIRCLE    SD  11/15/1956 18:30

# %%
ufo.sort_values(["City", "State"]).head(25)
# Out:
#                       City Colors Reported Shape Reported State  \
# 1761             Abbeville             NaN           DISK    SC
# 2297              Aberdeen             NaN       TRIANGLE    MD
# 9404              Aberdeen             NaN           DISK    MD
# 16167             Aberdeen             NaN        VARIOUS    OH
# 389               Aberdeen          ORANGE         CIRCLE    SD
# 4553              Aberdeen             NaN       CYLINDER    WA
# 12294             Aberdeen             NaN       FIREBALL    WA
# 14703             Aberdeen             NaN       TRIANGLE    WA
# 17809             Aberdeen           GREEN       FIREBALL    WA
# 3                  Abilene             NaN           DISK    KS
# 8783               Abilene             NaN            NaN    KS
# 6654               Abilene             NaN       TRIANGLE    TX
# 8357               Abilene             NaN         SPHERE    TX
# 10883              Abilene             NaN            NaN    TX
# ...

# %%
#City sorted according to state
ufo.sort_values(["State", "City"]).head(25)
# Out:
#                 City Colors Reported Shape Reported State              Time
# 5426            Adak             NaN          LIGHT    AK     6/1/1986 0:00
# 11130         Alaska             NaN           DISK    AK   1/15/1998 13:00
# 14405         Alaska             NaN          LIGHT    AK    9/1/1999 23:00
# 103        Anchorage             NaN           DISK    AK   6/10/1949 21:00
# 2304       Anchorage            BLUE         CIRCLE    AK    8/30/1972 1:30
# 5507       Anchorage             NaN           DISK    AK    8/20/1986 2:00
# 5765       Anchorage             NaN          LIGHT    AK   11/17/1987 6:00
# 7714       Anchorage             NaN          LIGHT    AK   1/17/1995 22:45
# 10454      Anchorage             NaN       CYLINDER    AK   6/30/1997 12:00
# 11314      Anchorage             NaN           OVAL    AK   3/15/1998 20:30
# 12470      Anchorage             NaN         CIRCLE    AK  10/31/1998 10:00
# ...
