# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,10,100) #generating 100 numbers from 0 to 10
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
plt.plot(x,x, label = "Linear") #plotting x against x

# %%
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.show()

# %%
import matplotlib.pyplot as plt
X = [590,540,740,130,810,300,320,230,470,620,770,250]
Y = [32,36,39,52,61,72,77,75,68,57,48,48]

plt.scatter(X,Y)
plt.show()

# %%
X = [590,540,740,130,810,300,320,230,470,620,770,250]
Y = [32,36,39,52,61,72,77,75,68,57,48,48]

plt.plot(X,Y)
plt.show() #plotting X and Y as xonnected

# %%
import numpy as np
import pylab as pl

# %%
#random.normal(loc=0.0, scale=1.0, size=None)
#loc float or array_like of floats  Mean (“centre”) of the distribution.
#scale float or array_like of floats
#Standard deviation (spread or “width”) of the distribution. Must be non-negative.

ds = np.random.normal(5.0, 3.0, 100)
ds
# Out:
# array([ 6.1644938 , 10.47768929,  1.28977023,  3.40888132, -0.15784091,
#         6.11249011,  5.53497722,  5.99158401,  8.04651751,  3.64270078,
#         6.07828761,  7.62301134,  4.61894319,  4.62691813,  3.84951965,
#         1.27560706,  0.69154443, 11.04406939,  3.37568777,  5.19008664,
#         7.16110252,  9.49928046,  7.32464434,  6.58407297,  4.59742385,
#         5.8398098 ,  4.84894297,  5.37460851,  3.89308253,  9.46104634,
#         8.7761152 ,  4.03312871,  8.75075324,  4.31658262,  7.1162372 ,
#         5.30361043,  3.3121368 , -1.13627923,  3.38787885,  3.36014158,
#         6.97331224,  0.62802366,  4.21961076,  6.26403417,  5.15516992,
#         6.21033578,  4.81431117,  5.71257518,  7.01248163, 10.62401147,
#         5.250177  ,  6.02978275,  6.63644518,  2.37501621,  8.65743634,
#         8.88526751,  0.80501844,  6.17822496, 10.23759325,  1.38749885,
#         9.84877327, 10.0424809 ,  6.41847393,  4.61857793,  2.37707239,
#        12.29848652,  5.33175402,  7.34809461,  0.78275664,  3.82081929,
#         8.08943726,  4.58305838,  5.1298918 ,  4.21730518,  5.03271016,
#         3.45530803,  7.11877605, 12.32415695, 11.03671476,  7.52506452,
#         3.73912543,  4.091708  ,  2.22292529,  4.51892234,  8.31858195,
#        11.75585317,  1.24468698,  4.92651971,  6.13145174,  7.26432881,
#         8.18274381,  6.43650806,  4.19652598, 10.51975236,  3.51002652,
#         1.86946699,  3.19158818,  0.94900089,  6.65864425,  3.90701191])

# %%
pl.hist(ds)
pl.xlabel("ds")
# Out:
# Text(0.5, 0, 'ds')
